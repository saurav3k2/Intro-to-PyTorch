# %%
def dy_dx(x):
  return 2*x

# %%
dy_dx(3)
# Out:
# 6

# %%
import torch

# %%
x= torch.tensor(3.0 ,requires_grad=True)

# %%
y = x**2

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %%
import math

def dz_dx(x):
  return 2* x * math.cos(x**2)

# %%
dz_dx(4)
# Out:
# -7.661275842587077

# %%
x = torch.tensor(4.0 , requires_grad=True)

# %%
y = x ** 2

# %%
z= torch.sin(y)

# %%
x
# Out:
# tensor(4., requires_grad=True)

# %%
y
# Out:
# tensor(16., grad_fn=<PowBackward0>)

# %%
z
# Out:
# tensor(-0.2879, grad_fn=<SinBackward0>)

# %%
z.backward()

# %%
x.grad
# Out:
# tensor(-7.6613)

# %%
y.grad
# Out:
# /tmp/ipython-input-486760323.py:1: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at /pytorch/build/aten/src/ATen/core/TensorBody.h:489.)
#   y.grad

# %%
import torch
# Inputs
x= torch.tensor(6.7)   # input feature
y= torch.tensor(0.0)   # True label (binary)


w = torch.tensor(1.0)   # Weights
b = torch.tensor(0.0)   # bias

# %%
# Binary Cross_Entropy loss for scalar

def binary_cross_entropy_loss(prediction , target):
  epsilon  = 1e-8 ## to prevent log(0)
  prediction = torch.clamp(prediction, epsilon , 1- epsilon)
  return -(target * torch.log(prediction) + (1- target) * torch.log(1- prediction))

# %%
# Forward pass
z= w*x + b   ## Weight sum (linear part)
y_pred = torch.sigmoid(z)   ## prevent log(0)


## comppyte binary cross-entropy loss
loss = binary_cross_entropy_loss(y_pred , y)

# %%
loss
# Out:
# tensor(6.7012)

# %%
## Dervivatives
# 1. dl/d(y_pred)  : loss with respect to the prediction (y_pred)
dloss_dy_pred = (y_pred -y  ) /(y_pred * (1- y_pred))

# 2. dy_pred / dz : prediction (y_pred)  with respect to z (sigmoid derivative)
dy_pred_dz = y_pred  * (1- y_pred)


# 3 . dz  / dw  and dz/db : z with respect to w and b
dz_dw = x   ## dz /dw = x
dz_db = 1   ## dz /db = 1  (bias contribites directly to z)

dl_dw = dloss_dy_pred * dy_pred_dz * dz_dw
dl_db = dloss_dy_pred * dy_pred_dz * dz_db

# %%
print(f"Mannul Gradient of loss w.r.t wieight (dw) : {dz_dw}")
print(f"Mannul Gradient of loss w.r.t biass(db) {dl_db}")
# Out:
# Mannul Gradient of loss w.r.t wieight (dw) : 6.699999809265137
# Mannul Gradient of loss w.r.t biass(db) 0.998770534992218

# %%
x = torch.tensor(6.7)
y = torch.tensor(0.0)

# %%
w = torch.tensor(1.0 , requires_grad=True)
b = torch.tensor(0.0 , requires_grad=True)

# %%
w
# Out:
# tensor(1., requires_grad=True)

# %%
b
# Out:
# tensor(0., requires_grad=True)

# %%
z = w * x + b

# %%
z
# Out:
# tensor(6.7000, grad_fn=<AddBackward0>)

# %%
y_pred = torch.sigmoid(z)

# %%
y_pred
# Out:
# tensor(0.9988, grad_fn=<SigmoidBackward0>)

# %%
loss = binary_cross_entropy_loss(y_pred , y)

# %%
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
print(w.grad)
print(b.grad)
# Out:
# tensor(6.6918)
# tensor(0.9988)

# %%
x = torch.tensor([1.0 , 2.0, 3.0] , requires_grad=True)

# %%
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y = (x**2).mean()
y
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %%
## Clearing grad
x  = torch.tensor(2.0, requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %%
x.grad.zero_()
# Out:
# tensor(0.)

# %%
## Disable gradient tracking
x = torch.tensor(2.0 , requires_grad= True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %%
## Option 1 - required_grad (False)
## Option 2 - detach()
## Option 3 - torch.no_grad()

# %%
x.requires_grad_(False)
# Out:
# tensor(2.)

# %%
x
# Out:
# tensor(2.)

# %%
y = x  ** 2

# %%
y
# Out:
# tensor(4.)

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-1055444503.py in <cell line: 0>()
# ----> 1 y.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     645                 inputs=inputs,
#     646             )
# --> 647         torch.autograd.backward(
#     648             self, gradient, retain_graph, create_graph, inputs=inputs
#     649         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# ...

# %%
x = torch.tensor(2.0, requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
z = x.detach()

# %%
z
# Out:
# tensor(2.)

# %%
y
# Out:
# tensor(4.)

# %%
y1 = z ** 2
y1
# Out:
# tensor(4.)

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-1055444503.py in <cell line: 0>()
# ----> 1 y.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     645                 inputs=inputs,
#     646             )
# --> 647         torch.autograd.backward(
#     648             self, gradient, retain_graph, create_graph, inputs=inputs
#     649         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# ...

# %%
y1.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-3844781142.py in <cell line: 0>()
# ----> 1 y1.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     645                 inputs=inputs,
#     646             )
# --> 647         torch.autograd.backward(
#     648             self, gradient, retain_graph, create_graph, inputs=inputs
#     649         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# ...

# %%
x = torch.tensor(2.0, requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()
